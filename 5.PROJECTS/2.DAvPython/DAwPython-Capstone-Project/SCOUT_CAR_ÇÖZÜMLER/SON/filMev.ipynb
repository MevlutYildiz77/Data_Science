# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")
import json
import requests
from pandas.io.json import json_normalize
import re

import warnings
warnings.filterwarnings("ignore")
warnings.warn("This will not show")

# %matplotlib inline

pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows',2000)
#pd.set_option('display.max_info_rows', 10)
#pd.set_option('display.max_colwidth', 100)
#pd.set_option('display.max_info_columns', 5000)
#pd.set_option('display.expand_frame_repr', True)
#pd.set_option('display.width', 10)

# %%
df = pd.read_csv('clean_scout2.1.csv')
df.T
# Out:
#                                                                  0      \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            15770
# vat                                                     VAT deductible
# km                                                             56013.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                       Black
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n3\n']
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media  Bluetooth,Hands-free equipment,On-board comput...
# Extras                  Alloy wheels,Catalytic Converter,Voice Control
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              NaN
# age                                                                3.0
# Previous_Owners                                                    2.0
# hp_kW                                                             66.0
# Inspection_new                                                     Yes
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        3.0
# Nr_of_Seats                                                        5.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1422.0
# Weight_kg                                                       1220.0
# Drive_chain                                                      front
# cons_comb                                                          3.8
# cons_city                                                          4.3
# cons_country                                                       3.5
# CO2_Emission                                                      99.0
# Emission_Class                                                  Euro 6
#
#                                                                  1      \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14500
# vat                                                   Price negotiable
# km                                                             80000.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                         Red
# Paint Type                                                         NaN
# Cylinders                                                    ['\n4\n']
# Fuel                                                           Benzine
# Comfort_Convenience  Air conditioning,Automatic climate control,Hil...
# Entertainment_Media  Bluetooth,Hands-free equipment,On-board comput...
# Extras               Alloy wheels,Sport seats,Sport suspension,Voic...
# Safety_Security      ABS,Central door lock,Central door lock with r...
# Gears                                                              7.0
# age                                                                2.0
# Previous_Owners                                                    NaN
# hp_kW                                                            141.0
# Inspection_new                                                     NaN
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        4.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1798.0
# Weight_kg                                                       1255.0
# Drive_chain                                                      front
# cons_comb                                                          5.6
# cons_city                                                          7.1
# cons_country                                                       4.7
# CO2_Emission                                                     129.0
# Emission_Class                                                  Euro 6
#
#                                                                  2      \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14640
# vat                                                     VAT deductible
# km                                                             83450.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                       Black
# Paint Type                                                \nMetallic\n
# Cylinders                                                          NaN
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Cruise control,Electrical sid...
# Entertainment_Media                              MP3,On-board computer
# Extras                                      Alloy wheels,Voice Control
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              NaN
# age                                                                3.0
# Previous_Owners                                                    1.0
# hp_kW                                                             85.0
# Inspection_new                                                     NaN
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        NaN
# Nr_of_Seats                                                        4.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1598.0
# Weight_kg                                                          NaN
# Drive_chain                                                      front
# cons_comb                                                          3.8
# cons_city                                                          4.4
# cons_country                                                       3.4
# CO2_Emission                                                      99.0
# Emission_Class                                                  Euro 6
#
#                                                                  3      \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14500
# vat                                                                NaN
# km                                                             73000.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                       Brown
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n3\n']
# Fuel                                                            Diesel
# Comfort_Convenience  Air suspension,Armrest,Auxiliary heating,Elect...
# Entertainment_Media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# Extras                          Alloy wheels,Sport seats,Voice Control
# Safety_Security      ABS,Alarm system,Central door lock with remote...
# Gears                                                              6.0
# age                                                                3.0
# Previous_Owners                                                    1.0
# hp_kW                                                             66.0
# Inspection_new                                                     NaN
# Upholstery_type                                                    NaN
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        3.0
# Nr_of_Seats                                                        4.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1422.0
# Weight_kg                                                       1195.0
# Drive_chain                                                        NaN
# cons_comb                                                          3.8
# cons_city                                                          4.3
# cons_country                                                       3.5
# CO2_Emission                                                      99.0
# Emission_Class                                                  Euro 6
#
#                                                                  4      \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            16790
# vat                                                                NaN
# km                                                             16200.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                       Black
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n3\n']
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# Extras               Alloy wheels,Sport package,Sport suspension,Vo...
# Safety_Security      ABS,Central door lock,Driver-side airbag,Elect...
# Gears                                                              NaN
# age                                                                3.0
# Previous_Owners                                                    1.0
# hp_kW                                                             66.0
# Inspection_new                                                     Yes
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        3.0
# Nr_of_Seats                                                        5.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1422.0
# Weight_kg                                                          NaN
# Drive_chain                                                      front
# cons_comb                                                          4.1
# cons_city                                                          4.6
# cons_country                                                       3.8
# CO2_Emission                                                     109.0
# Emission_Class                                                  Euro 6
#
#                                                                  5      \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            15090
# vat                                                                NaN
# km                                                             63668.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                       White
# Paint Type                                                \nMetallic\n
# Cylinders                                                          NaN
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media  Bluetooth,Hands-free equipment,On-board comput...
# Extras               Alloy wheels,Sport package,Sport seats,Sport s...
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              NaN
# age                                                                3.0
# Previous_Owners                                                    1.0
# hp_kW                                                             85.0
# Inspection_new                                                     NaN
# Upholstery_type                                           Part leather
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        NaN
# Nr_of_Seats                                                        5.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1598.0
# Weight_kg                                                          NaN
# Drive_chain                                                        NaN
# cons_comb                                                          3.5
# cons_city                                                          4.3
# cons_country                                                       3.1
# CO2_Emission                                                      92.0
# Emission_Class                                                  Euro 6
#
#                                                                  6      \
# make_model                                                     Audi A1
# body_type                                                Station wagon
# price                                                            16422
# vat                                                     VAT deductible
# km                                                             62111.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                       White
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n4\n']
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media  Bluetooth,CD player,Hands-free equipment,On-bo...
# Extras               Alloy wheels,Sport package,Sport seats,Sport s...
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              NaN
# age                                                                3.0
# Previous_Owners                                                    1.0
# hp_kW                                                             85.0
# Inspection_new                                                     Yes
# Upholstery_type                                           Part leather
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        5.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1598.0
# Weight_kg                                                          NaN
# Drive_chain                                                      front
# cons_comb                                                          3.7
# cons_city                                                          4.3
# cons_country                                                       3.4
# CO2_Emission                                                      98.0
# Emission_Class                                                  Euro 6
#
#                                                                  7      \
# make_model                                                     Audi A1
# body_type                                                      Compact
# price                                                            14480
# vat                                                     VAT deductible
# km                                                             14986.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                         Red
# Paint Type                                                \nMetallic\n
# Cylinders                                                          NaN
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Armrest,Electrical side mirro...
# Entertainment_Media                                CD player,MP3,Radio
# Extras                                                    Alloy wheels
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              7.0
# age                                                                3.0
# Previous_Owners                                                    1.0
# hp_kW                                                             66.0
# Inspection_new                                                     Yes
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        NaN
# Nr_of_Seats                                                        5.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1422.0
# Weight_kg                                                          NaN
# Drive_chain                                                      front
# cons_comb                                                          3.7
# cons_city                                                          4.2
# cons_country                                                       3.4
# CO2_Emission                                                      97.0
# Emission_Class                                                  Euro 6
#
#                                                                  8      \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            16700
# vat                                                                NaN
# km                                                             57000.0
# Type                                                              Used
# Warranty                                                          12.0
# Body Color                                                        Grey
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n4\n']
# Fuel                                                            Diesel
# Comfort_Convenience                     Air conditioning,Power windows
# Entertainment_Media                                              Radio
# Extras                                                    Alloy wheels
# Safety_Security      ABS,Central door lock,Driver-side airbag,Elect...
# Gears                                                              7.0
# age                                                                3.0
# Previous_Owners                                                    1.0
# hp_kW                                                             85.0
# Inspection_new                                                     NaN
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        4.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1598.0
# Weight_kg                                                       1275.0
# Drive_chain                                                      front
# cons_comb                                                          3.7
# cons_city                                                          4.3
# cons_country                                                       3.4
# CO2_Emission                                                      97.0
# Emission_Class                                                  Euro 6
#
#                          9      \
# make_model             Audi A1
# body_type               Sedans
# price                    17990
# vat                        NaN
# km                     16103.0
# Type                      Used
# Warranty                   3.0
# Body Color               White
# Paint Type                 NaN
# Cylinders                  NaN
# Fuel                   Benzine
# Comfort_Convenience        NaN
# Entertainment_Media        NaN
# Extras                     NaN
# Safety_Security            NaN
# Gears                      7.0
# age                        2.0
# Previous_Owners            NaN
# hp_kW                     70.0
# Inspection_new             NaN
# Upholstery_type            NaN
# Upholstery_color           NaN
# Nr_of_Doors                NaN
# Nr_of_Seats                4.0
# Gearing_Type         Automatic
# Displacement_cc          999.0
# Weight_kg                  NaN
# Drive_chain                NaN
# cons_comb                  NaN
# cons_city                  NaN
# cons_country               NaN
# CO2_Emission               NaN
# Emission_Class             NaN
#
#                                                                  10     \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            18500
# vat                                                     VAT deductible
# km                                                             11300.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                       Black
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n4\n']
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Multi-function steering wheel...
# Entertainment_Media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# Extras                                      Alloy wheels,Shift paddles
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              7.0
# age                                                                1.0
# Previous_Owners                                                    NaN
# hp_kW                                                             85.0
# Inspection_new                                                     NaN
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        4.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1598.0
# Weight_kg                                                       1250.0
# Drive_chain                                                      front
# cons_comb                                                          4.0
# cons_city                                                          4.6
# cons_country                                                       3.6
# CO2_Emission                                                     105.0
# Emission_Class                                                  Euro 6
#
#                                                                  11     \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            17990
# vat                                                                NaN
# km                                                             26415.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                      Silver
# Paint Type                                               \nUni/basic\n
# Cylinders                                                    ['\n4\n']
# Fuel                                                           Benzine
# Comfort_Convenience  Air conditioning,Automatic climate control,Ele...
# Entertainment_Media  CD player,Hands-free equipment,On-board comput...
# Extras                                        Alloy wheels,Sport seats
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              NaN
# age                                                                3.0
# Previous_Owners                                                    1.0
# hp_kW                                                             92.0
# Inspection_new                                                     Yes
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        NaN
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1395.0
# Weight_kg                                                          NaN
# Drive_chain                                                      front
# cons_comb                                                          4.9
# cons_city                                                          6.2
# cons_country                                                       4.2
# CO2_Emission                                                     112.0
# Emission_Class                                                  Euro 6
#
#                                                                  12     \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            18380
# vat                                                                NaN
# km                                                             31600.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                       White
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n4\n']
# Fuel                                                           Benzine
# Comfort_Convenience  Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# Extras               Alloy wheels,Catalytic Converter,Sport package...
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              NaN
# age                                                                3.0
# Previous_Owners                                                    1.0
# hp_kW                                                             92.0
# Inspection_new                                                     NaN
# Upholstery_type                                           Part leather
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        5.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1395.0
# Weight_kg                                                          NaN
# Drive_chain                                                      front
# cons_comb                                                          4.9
# cons_city                                                          6.2
# cons_country                                                       4.2
# CO2_Emission                                                     112.0
# Emission_Class                                                  Euro 6
#
#                                                                  13     \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            18399
# vat                                                                NaN
# km                                                             45764.0
# Type                                                              Used
# Warranty                                                          12.0
# Body Color                                                        Grey
# Paint Type                                                         NaN
# Cylinders                                                          NaN
# Fuel                                                           Benzine
# Comfort_Convenience  Air conditioning,Automatic climate control,Cru...
# Entertainment_Media                  Bluetooth,On-board computer,Radio
# Extras                       Alloy wheels,Sport seats,Sport suspension
# Safety_Security      ABS,Adaptive headlights,Central door lock,Dayt...
# Gears                                                              NaN
# age                                                                3.0
# Previous_Owners                                                    NaN
# hp_kW                                                            112.0
# Inspection_new                                                     NaN
# Upholstery_type                                                    NaN
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        NaN
# Nr_of_Seats                                                        4.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1395.0
# Weight_kg                                                          NaN
# Drive_chain                                                        NaN
# cons_comb                                                          NaN
# cons_city                                                          NaN
# cons_country                                                       NaN
# CO2_Emission                                                       NaN
# Emission_Class                                                     NaN
#
#                                                                  14     \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            17990
# vat                                                     VAT deductible
# km                                                             34914.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                       Black
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n3\n']
# Fuel                                                           Benzine
# Comfort_Convenience  Air conditioning,Automatic climate control,Cru...
# Entertainment_Media  Bluetooth,CD player,Hands-free equipment,On-bo...
# Extras                       Alloy wheels,Sport seats,Sport suspension
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              7.0
# age                                                                3.0
# Previous_Owners                                                    1.0
# hp_kW                                                             70.0
# Inspection_new                                                     NaN
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        3.0
# Nr_of_Seats                                                        4.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                  999.0
# Weight_kg                                                       1135.0
# Drive_chain                                                      front
# cons_comb                                                          4.2
# cons_city                                                          5.0
# cons_country                                                       3.7
# CO2_Emission                                                      99.0
# Emission_Class                                                  Euro 6
#
#                                                                  15     \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            18700
# vat                                                     VAT deductible
# km                                                             27000.0
# Type                                                    Employee's car
# Warranty                                                          12.0
# Body Color                                                        Grey
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n4\n']
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Armrest,Cruise control,Electr...
# Entertainment_Media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# Extras                                                    Alloy wheels
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              7.0
# age                                                                3.0
# Previous_Owners                                                    1.0
# hp_kW                                                             85.0
# Inspection_new                                                     NaN
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        4.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1598.0
# Weight_kg                                                       1275.0
# Drive_chain                                                      front
# cons_comb                                                          3.7
# cons_city                                                          4.3
# cons_country                                                       3.4
# CO2_Emission                                                      97.0
# Emission_Class                                                  Euro 6
#
#                                                                  16     \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            18900
# vat                                                     VAT deductible
# km                                                              9752.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                        Blue
# Paint Type                                                         NaN
# Cylinders                                                    ['\n4\n']
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Leather steering wheel,Power ...
# Entertainment_Media                                CD player,MP3,Radio
# Extras                          Alloy wheels,Sport package,Sport seats
# Safety_Security      Central door lock,Driver-side airbag,Electroni...
# Gears                                                              5.0
# age                                                                1.0
# Previous_Owners                                                    NaN
# hp_kW                                                             85.0
# Inspection_new                                                     NaN
# Upholstery_type                                                    NaN
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        4.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1598.0
# Weight_kg                                                       1175.0
# Drive_chain                                                      front
# cons_comb                                                          3.5
# cons_city                                                          4.3
# cons_country                                                       3.1
# CO2_Emission                                                      92.0
# Emission_Class                                                  Euro 6
#
#                                                                  17     \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            18500
# vat                                                     VAT deductible
# km                                                             28408.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                       White
# Paint Type                                                         NaN
# Cylinders                                                    ['\n3\n']
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Automatic climate control,Cru...
# Entertainment_Media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# Extras                                      Alloy wheels,Sport package
# Safety_Security      ABS,Alarm system,Central door lock,Central doo...
# Gears                                                              7.0
# age                                                                2.0
# Previous_Owners                                                    1.0
# hp_kW                                                             66.0
# Inspection_new                                                     NaN
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        3.0
# Nr_of_Seats                                                        5.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1422.0
# Weight_kg                                                       1220.0
# Drive_chain                                                      front
# cons_comb                                                          3.8
# cons_city                                                          4.3
# cons_country                                                       3.5
# CO2_Emission                                                      99.0
# Emission_Class                                                  Euro 6
#
#                                                                  18     \
# make_model                                                     Audi A1
# body_type                                                      Compact
# price                                                            18400
# vat                                                     VAT deductible
# km                                                             50280.0
# Type                                                              Used
# Warranty                                                           6.0
# Body Color                                                       Black
# Paint Type                                                         NaN
# Cylinders                                                    ['\n3\n']
# Fuel                                                           Benzine
# Comfort_Convenience  Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media  Bluetooth,CD player,Hands-free equipment,On-bo...
# Extras                                                    Alloy wheels
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              7.0
# age                                                                3.0
# Previous_Owners                                                    NaN
# hp_kW                                                             70.0
# Inspection_new                                                     NaN
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        3.0
# Nr_of_Seats                                                        5.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                  999.0
# Weight_kg                                                       1065.0
# Drive_chain                                                        NaN
# cons_comb                                                          4.5
# cons_city                                                          5.5
# cons_country                                                       3.9
# CO2_Emission                                                     103.0
# Emission_Class                                                  Euro 6
#
#                                                                  19     \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            18500
# vat                                                     VAT deductible
# km                                                             13406.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                       Black
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n4\n']
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Armrest,Auxiliary heating,Ele...
# Entertainment_Media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# Extras               Alloy wheels,Catalytic Converter,Shift paddles...
# Safety_Security      Alarm system,Central door lock,Daytime running...
# Gears                                                              7.0
# age                                                                1.0
# Previous_Owners                                                    NaN
# hp_kW                                                             85.0
# ...
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        5.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1997.0
# Weight_kg                                                       1758.0
# Drive_chain                                                      front
# cons_comb                                                          5.3
# cons_city                                                          6.2
# cons_country                                                       4.7
# CO2_Emission                                                     139.0
# Emission_Class                                                     NaN
#
#                                                                  15913  \
# make_model                                              Renault Espace
# body_type                                                          Van
# price                                                            39950
# vat                                                     VAT deductible
# km                                                              1000.0
# Type                                                     Demonstration
# Warranty                                                           NaN
# Body Color                                                       White
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n4\n']
# Fuel                                                           Benzine
# Comfort_Convenience  Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media  Bluetooth,Digital radio,Hands-free equipment,M...
# Extras               Alloy wheels,Catalytic Converter,Sport suspens...
# Safety_Security      ABS,Adaptive Cruise Control,Blind spot monitor...
# Gears                                                              NaN
# age                                                                0.0
# Previous_Owners                                                    NaN
# hp_kW                                                            165.0
# Inspection_new                                                     NaN
# Upholstery_type                                           Full leather
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        7.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1798.0
# Weight_kg                                                          NaN
# Drive_chain                                                      front
# cons_comb                                                          6.8
# cons_city                                                          8.7
# cons_country                                                       5.7
# CO2_Emission                                                     153.0
# Emission_Class                                                  Euro 6
#
#                                                                  15914  \
# make_model                                              Renault Espace
# body_type                                                          Van
# price                                                            39950
# vat                                                     VAT deductible
# km                                                                 NaN
# Type                                                               New
# Warranty                                                          24.0
# Body Color                                                        Grey
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n4\n']
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Automatic climate control,Cru...
# Entertainment_Media  Bluetooth,Digital radio,Hands-free equipment,O...
# Extras                                       Alloy wheels,Touch screen
# Safety_Security      ABS,Central door lock,Central door lock with r...
# Gears                                                              6.0
# age                                                                NaN
# Previous_Owners                                                    NaN
# hp_kW                                                            147.0
# Inspection_new                                                     NaN
# Upholstery_type                                                    NaN
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        5.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1997.0
# Weight_kg                                                       1758.0
# Drive_chain                                                      front
# cons_comb                                                          5.3
# cons_city                                                          6.2
# cons_country                                                       4.7
# CO2_Emission                                                     139.0
# Emission_Class                                                     NaN
#
#                                                                  15915  \
# make_model                                              Renault Espace
# body_type                                                          Van
# price                                                            39885
# vat                                                     VAT deductible
# km                                                              9900.0
# Type                                                              Used
# Warranty                                                           NaN
# Body Color                                                        Grey
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n4\n']
# Fuel                                                           Benzine
# Comfort_Convenience  Air conditioning,Automatic climate control,Cru...
# Entertainment_Media  Bluetooth,Digital radio,Hands-free equipment,R...
# Extras                         Alloy wheels,Touch screen,Voice Control
# Safety_Security      ABS,Adaptive Cruise Control,Blind spot monitor...
# Gears                                                              7.0
# age                                                                0.0
# Previous_Owners                                                    1.0
# hp_kW                                                            165.0
# Inspection_new                                                     NaN
# Upholstery_type                                                  Cloth
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        5.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1798.0
# Weight_kg                                                       1708.0
# Drive_chain                                                      front
# cons_comb                                                          7.4
# cons_city                                                          9.2
# cons_country                                                       6.3
# CO2_Emission                                                     168.0
# Emission_Class                                                     NaN
#
#                                                                  15916  \
# make_model                                              Renault Espace
# body_type                                                          Van
# price                                                            39875
# vat                                                     VAT deductible
# km                                                                15.0
# Type                                                    Pre-registered
# Warranty                                                           NaN
# Body Color                                                       White
# Paint Type                                                         NaN
# Cylinders                                                    ['\n4\n']
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media  Bluetooth,Hands-free equipment,On-board comput...
# Extras                                                    Alloy wheels
# Safety_Security      ABS,Adaptive Cruise Control,Blind spot monitor...
# Gears                                                              6.0
# age                                                                0.0
# Previous_Owners                                                    1.0
# hp_kW                                                            146.0
# Inspection_new                                                     Yes
# Upholstery_type                                           Full leather
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        7.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1997.0
# Weight_kg                                                          NaN
# Drive_chain                                                      front
# cons_comb                                                          5.3
# cons_city                                                          6.2
# cons_country                                                       4.7
# CO2_Emission                                                     139.0
# Emission_Class                                                  Euro 6
#
#                                                                  15917  \
# make_model                                              Renault Espace
# body_type                                                          Van
# price                                                            39700
# vat                                                     VAT deductible
# km                                                                10.0
# Type                                                    Pre-registered
# Warranty                                                           NaN
# Body Color                                                        Grey
# Paint Type                                                         NaN
# Cylinders                                                    ['\n4\n']
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Automatic climate control,Cru...
# Entertainment_Media                  Bluetooth,Digital radio,Radio,USB
# Extras                                       Alloy wheels,Touch screen
# Safety_Security      ABS,Blind spot monitor,Driver-side airbag,Elec...
# Gears                                                              6.0
# age                                                                0.0
# Previous_Owners                                                    NaN
# hp_kW                                                            147.0
# Inspection_new                                                     NaN
# Upholstery_type                                           Part leather
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        7.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1997.0
# Weight_kg                                                       1758.0
# Drive_chain                                                      front
# cons_comb                                                          5.3
# cons_city                                                          6.2
# cons_country                                                       4.7
# CO2_Emission                                                     139.0
# Emission_Class                                                  Euro 6
#
#                                                                  15918
# make_model                                              Renault Espace
# body_type                                                          Van
# price                                                            40999
# vat                                                     VAT deductible
# km                                                                 NaN
# Type                                                     Demonstration
# Warranty                                                           NaN
# Body Color                                                        Grey
# Paint Type                                                \nMetallic\n
# Cylinders                                                    ['\n4\n']
# Fuel                                                           Benzine
# Comfort_Convenience  Air conditioning,Automatic climate control,Cru...
# Entertainment_Media                                                USB
# Extras                                       Alloy wheels,Touch screen
# Safety_Security      ABS,Blind spot monitor,Daytime running lights,...
# Gears                                                              NaN
# age                                                                0.0
# Previous_Owners                                                    1.0
# hp_kW                                                            165.0
# Inspection_new                                                     Yes
# Upholstery_type                                           Full leather
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                        4.0
# Nr_of_Seats                                                        5.0
# Gearing_Type                                                 Automatic
# Displacement_cc                                                 1798.0
# Weight_kg                                                       1685.0
# Drive_chain                                                        4WD
# cons_comb                                                          6.8
# cons_city                                                          8.7
# cons_country                                                       5.7
# CO2_Emission                                                     153.0
# Emission_Class                                                  Euro 6
#
# [33 rows x 15919 columns]

# %%
df.describe().T
# Out:
#                    count          mean          std   min      25%      50%  \
# price            15919.0  18019.896727  7386.169409  13.0  12850.0  16900.0
# Warranty          4853.0     21.927261    15.771120   1.0     12.0     12.0
# Gears            11207.0      5.924601     0.848158   1.0      5.0      6.0
# age              14322.0      1.542382     1.076917   0.0      1.0      1.0
# Previous_Owners   9279.0      1.067895     0.329812   0.0      1.0      1.0
# hp_kW            15831.0     88.367696    26.835135   1.0     66.0     85.0
# Nr_of_Doors      10239.0      3.797343     0.415382   1.0      4.0      4.0
# Nr_of_Seats      14942.0      4.949873     0.489872   2.0      5.0      5.0
# Displacement_cc  15423.0   1423.540881   333.530658   1.0   1229.0   1461.0
# Weight_kg         8945.0   1351.106540   220.661532   1.0   1165.0   1288.0
# cons_comb        13886.0      4.895549     1.635382   0.0      4.1      4.8
# cons_city        13483.0      5.947801     1.966939   0.0      4.7      5.8
# cons_country     13543.0      4.238404     1.194201   0.0      3.7      4.2
# CO2_Emission     13483.0    123.739672   269.952395   0.0    104.0    116.0
#
#                      75%      max
# price            21900.0  74600.0
# Warranty            24.0     72.0
# Gears                6.0     50.0
# age                  3.0      3.0
# Previous_Owners      1.0      4.0
# hp_kW              101.0    294.0
# Nr_of_Doors          4.0      8.0
# Nr_of_Seats          5.0      7.0
# Displacement_cc   1598.0  16000.0
# Weight_kg         1487.0   2471.0
# cons_comb            5.5     55.0
# cons_city            7.0     66.0
# cons_country         4.6     44.0
# CO2_Emission       129.0  14457.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           15919 non-null  object
#  1   body_type            15859 non-null  object
#  2   price                15919 non-null  int64
#  3   vat                  11406 non-null  object
#  4   km                   15919 non-null  object
#  5   Type                 15917 non-null  object
#  6   Warranty             4853 non-null   float64
#  7   Body Color           15322 non-null  object
#  8   Paint Type           10147 non-null  object
#  9   Cylinders            10239 non-null  object
#  10  Fuel                 15919 non-null  object
#  11  Comfort_Convenience  14999 non-null  object
#  12  Entertainment_Media  14545 non-null  object
#  13  Extras               12957 non-null  object
#  14  Safety_Security      14937 non-null  object
#  15  Gears                11207 non-null  float64
#  16  age                  14322 non-null  float64
#  17  Previous_Owners      9279 non-null   float64
#  18  hp_kW                15831 non-null  float64
#  19  Inspection_new       3932 non-null   object
#  20  Upholstery_type      11048 non-null  object
#  21  Upholstery_color     783 non-null    object
#  22  Nr_of_Doors          10239 non-null  float64
#  23  Nr_of_Seats          14942 non-null  float64
#  24  Gearing_Type         15919 non-null  object
#  25  Displacement_cc      15423 non-null  float64
#  26  Weight_kg            8945 non-null   float64
#  27  Drive_chain          9061 non-null   object
#  28  cons_comb            13886 non-null  float64
#  29  cons_city            13483 non-null  float64
#  30  cons_country         13543 non-null  float64
#  31  CO2_Emission         13483 non-null  float64
#  32  Emission_Class       12291 non-null  object
# dtypes: float64(13), int64(1), object(19)
# memory usage: 4.0+ MB

# %%
(df.isnull().sum()/df.shape[0]*100).sort_values(ascending=False)
# Out:
# Upholstery_color       95.081349
# Inspection_new         75.299956
# Warranty               69.514417
# Weight_kg              43.809285
# Drive_chain            43.080596
# Previous_Owners        41.711163
# Paint Type             36.258559
# Nr_of_Doors            35.680633
# Cylinders              35.680633
# Upholstery_type        30.598656
# Gears                  29.599849
# vat                    28.349771
# Emission_Class         22.790376
# Extras                 18.606696
# cons_city              15.302469
# CO2_Emission           15.302469
# cons_country           14.925561
# cons_comb              12.770903
# age                    10.032037
# Entertainment_Media     8.631195
# Safety_Security         6.168729
# Nr_of_Seats             6.137320
# Comfort_Convenience     5.779257
# Body Color              3.750236
# Displacement_cc         3.115774
# hp_kW                   0.552799
# body_type               0.376908
# Type                    0.012564
# Gearing_Type            0.000000
# Fuel                    0.000000
# km                      0.000000
# price                   0.000000
# make_model              0.000000
# dtype: float64

# %%
df.shape
# Out:
# (15919, 33)

# %%
def fill_most(df, group_col, col_name):
    
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        mode = list(df[cond][col_name].mode())
        if mode != []:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[cond][col_name].mode()[0])
        else:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[col_name].mode()[0])

# %%
def fill_prop(df, group_col, col_name):
    
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        df.loc[cond, col_name] = df.loc[cond, col_name].fillna(method="ffill").fillna(method="bfill")
    df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")

# %%
def fill(df, group_col1, group_col2, col_name, method): 
    if method == "mode":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                mode1 = list(df[cond1][col_name].mode())
                mode2 = list(df[cond2][col_name].mode())
                if mode2 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mode()[0])
                elif mode1 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond1][col_name].mode()[0])
                else:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[col_name].mode()[0])
                
    elif method == "median":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].median()).fillna(df[cond1][col_name].median()).fillna(df[col_name].median())
                
    elif method == "ffill":           
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(method="ffill").fillna(method="bfill")
                
        for group1 in list(df[group_col1].unique()):
            cond1 = df[group_col1]==group1
            df.loc[cond1, col_name] = df.loc[cond1, col_name].fillna(method="ffill").fillna(method="bfill")            
           
        df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")

# %% [markdown]
# # 2. searchıng each rows

# %% [markdown]
# # age

# %%
df["age"].value_counts(dropna=False)
# Out:
# 1.0    4522
# 3.0    3674
# 2.0    3273
# 0.0    2853
# NaN    1597
# Name: age, dtype: int64

# %%
df['age'].fillna('?', inplace=True)

# %%
df["age"].value_counts(dropna=False)
# Out:
# 1.0    4522
# 3.0    3674
# 2.0    3273
# 0.0    2853
# ?      1597
# Name: age, dtype: int64

# %%
df.groupby("age").km.describe()
# Out:
#       count          mean           std   min       25%      50%      75%  \
# age
# 0.0  2706.0   2085.355137   5365.880693   1.0     10.00     50.0   3000.0
# 1.0  4484.0  18035.239072  11052.524314   1.0   9990.00  17872.0  25078.5
# 2.0  3272.0  41754.940709  28295.747886   1.0  21541.75  34752.0  54805.5
# 3.0  3674.0  77442.520958  39170.142977  10.0  48000.00  72914.5  99950.0
# ?     759.0    934.496706   7416.243875   0.0      5.00     10.0     10.0
#
#           max
# age
# 0.0  127022.0
# 1.0  136000.0
# 2.0  317000.0
# 3.0  291800.0
# ?     89982.0

# %%
df.km.value_counts(dropna=False).sort_values(ascending=True)
# Out:
# 25308.0       1
# 88123.0       1
# 72192.0       1
# 74182.0       1
# 73945.0       1
#            ...
# 50.0        148
# 5.0         170
# 1.0         367
# NaN        1024
# 10.0       1045
# Name: km, Length: 6690, dtype: int64

# %%
df[df["age"]=="?"]["km"].value_counts(dropna=False)
# Out:
# NaN        838
# 10.0       369
# 1.0        146
# 5.0         58
# 20.0        32
# 15.0        21
# 0.0         19
# 11.0        12
# 8.0         11
# 50.0        10
# 100.0        8
# 12.0         8
# 7.0          7
# 3.0          4
# 9.0          4
# 4.0          3
# 25.0         3
# 250.0        3
# 30.0         3
# 3000.0       2
# 22627.0      2
# 39962.0      2
# 2.0          2
# 19500.0      1
# 11000.0      1
# 85000.0      1
# 4307.0       1
# 89692.0      1
# 77.0         1
# 3500.0       1
# 68485.0      1
# 5000.0       1
# 141.0        1
# 150.0        1
# 34164.0      1
# 142.0        1
# 32084.0      1
# 81800.0      1
# 11200.0      1
# 20768.0      1
# 4500.0       1
# 40.0         1
# 784.0        1
# 89982.0      1
# 500.0        1
# 325.0        1
# 6100.0       1
# 196.0        1
# 6.0          1
# 60.0         1
# 497.0        1
# 99.0         1
# 281.0        1
# Name: km, dtype: int64

# %%
df.groupby("km").age.describe()
# Out:
#           count unique  top   freq
# km
# 0.0          19      1    ?     19
# 1.0       367.0    4.0  0.0  194.0
# 2.0         6.0    2.0  0.0    4.0
# 3.0        33.0    2.0  0.0   29.0
# 4.0        15.0    3.0  0.0   10.0
# ...         ...    ...  ...    ...
# 240000.0    1.0    1.0  2.0    1.0
# 248000.0    1.0    1.0  3.0    1.0
# 260000.0    1.0    1.0  3.0    1.0
# 291800.0    1.0    1.0  3.0    1.0
# 317000.0    1.0    1.0  2.0    1.0
#
# [6689 rows x 4 columns]

# %%
cond1 = (df['km'] < 8000)
cond2 = ((df['km'] >= 8000) & (df['km'] < 30000))
cond3 = ((df['km'] >= 30000) & (df['km'] < 70000))
cond4 = (df['km'] >= 70000)

# %%
df.loc[cond1,'age'] = df.loc[cond1,'age'].replace('?', 0)
df.loc[cond2,'age'] = df.loc[cond2,'age'].replace('?', 1)
df.loc[cond3,'age'] = df.loc[cond3,'age'].replace('?', 2)
df.loc[cond4,'age'] = df.loc[cond4,'age'].replace('?', 3)

# %%
df.groupby('age').km.mean()
# Out:
# age
# 0.0     1647.362609
# 1.0    18035.130067
# 2.0    41756.735734
# 3.0    77452.500272
# ?               NaN
# Name: km, dtype: float64

# %%
df["age"].value_counts(dropna=False)
# Out:
#     Opel Insignia   568.0  93182.341549  41020.813521  10791.0  63000.00
#     Renault Clio    413.0  68615.435835  35580.166690     10.0  42208.00
#     Renault Espace  300.0  74400.566667  34189.092815   3532.0  49975.00
# ?   Audi A1           0.0           NaN           NaN      NaN       NaN
#     Audi A3           0.0           NaN           NaN      NaN       NaN
#     Opel Astra        0.0           NaN           NaN      NaN       NaN
#     Opel Corsa        0.0           NaN           NaN      NaN       NaN
#     Opel Insignia     0.0           NaN           NaN      NaN       NaN
#     Renault Clio      0.0           NaN           NaN      NaN       NaN
#     Renault Duster    0.0           NaN           NaN      NaN       NaN
#     Renault Espace    0.0           NaN           NaN      NaN       NaN
#
#                         50%        75%       max
# age make_model
# 0.0 Audi A1           100.0    3333.00   18000.0
#     Audi A3            10.0     100.00  127022.0
#     Opel Astra         50.0    3698.00   88000.0
#     Opel Corsa         10.0     100.00   76300.0
#     Opel Insignia      77.0    3995.00   37500.0
#     Renault Clio       10.0      50.00  105000.0
#     Renault Duster    101.0     101.00     101.0
#     Renault Espace     15.0    1000.00   19900.0
# 1.0 Audi A1         12413.0   20309.75   47000.0
#     Audi A2         26166.0   26166.00   26166.0
#     Audi A3         18000.0   24215.00  136000.0
#     Opel Astra      22000.0   28466.00   67500.0
#     Opel Corsa      16617.0   24500.00   70000.0
#     Opel Insignia   23928.0   28460.00   70670.0
#     Renault Clio    13685.0   23308.00  113392.0
#     Renault Espace  13625.0   20900.00   62860.0
# 2.0 Audi A1         20730.5   32028.75  148257.0
#     Audi A3         36677.0   55251.00  158000.0
#     Opel Astra      44287.5   69187.00  188000.0
#     Opel Corsa      39905.5   54679.25  317000.0
#     Opel Insignia   33900.0   77125.00  180033.0
#     Renault Clio    32713.0   46000.00  131494.0
#     Renault Espace  41115.5   49606.00  240000.0
# 3.0 Audi A1         50000.0   65500.00  192000.0
#     Audi A3         88000.0  112562.50  291800.0
#     Opel Astra      84950.0  112388.00  260000.0
#     Opel Corsa      55484.0   90000.00  179521.0
#     Opel Insignia   88808.5  117500.00  232000.0
#     Renault Clio    63404.0   92000.00  163500.0
#     Renault Espace  68766.0   95000.00  197414.0
# ?   Audi A1             NaN        NaN       NaN
#     Audi A3             NaN        NaN       NaN
#     Opel Astra          NaN        NaN       NaN
#     Opel Corsa          NaN        NaN       NaN
#     Opel Insignia       NaN        NaN       NaN
#     Renault Clio        NaN        NaN       NaN
#     Renault Duster      NaN        NaN       NaN
#     Renault Espace      NaN        NaN       NaN

# %%
df.groupby(['make_model',"body_type", 'age']).price.describe()
# Out:
#                                   count          mean           std      min  \
# make_model     body_type     age
# Audi A1        Compact       0.0  198.0  23277.434343   3510.405726  14900.0
#                              1.0  268.0  18596.041045   2659.909876  13980.0
#                              2.0  161.0  16602.807453   2085.383788  10999.0
#                              3.0  234.0  14532.910256   1908.908968   9950.0
#                              ?    178.0  23996.264045   3383.852477  16220.0
#                Coupe         2.0    1.0  15900.000000           NaN  15900.0
#                              3.0    1.0  13950.000000           NaN  13950.0
#                              1.0  34000.00  34000.0  34000.00  34000.0
#                              2.0  23400.00  24900.0  26400.00  27900.0
#                              3.0  21745.00  25990.0  29445.00  32900.0
#                Sedans        0.0  48498.00  48498.0  48498.00  48498.0
#                              1.0  25995.00  28990.0  30900.00  36900.0
#                              2.0  23800.00  23800.0  23895.00  23990.0
#                              3.0  20724.25  22449.5  24174.75  25900.0
#                              ?    42506.00  43969.0  45432.00  46895.0
#                Station wagon 0.0  42490.00  42680.0  43790.00  52990.0
#                              1.0  30230.00  35370.0  37730.00  39990.0
#                              2.0  23400.00  27500.0  30980.00  33900.0
#                              3.0  19950.00  20455.0  23605.00  27500.0
#                              ?    42740.00  42990.0  46970.00  50950.0
#                Transporter   0.0  32700.00  32700.0  32700.00  32700.0
#                              1.0  27999.00  29500.0  30000.00  31000.0
#                              2.0  21000.00  25000.0  27000.00  28300.0
#                              3.0  19000.00  20500.0  24200.00  30000.0
#                Van           0.0  32975.00  38925.0  45667.25  68320.0
#                              1.0  29385.00  31900.0  34990.00  38990.0
#                              2.0  24982.50  25490.0  28500.00  33800.0
#                              3.0  19900.00  22222.0  24650.00  27900.0
#                              ?    33848.00  39550.0  45950.50  50170.0

# %%
df['age'].replace('?',1, inplace=True)

# %%
df.groupby('age').km.mean()
# Out:
# age
# 0.0     1647.362609
# 1.0    18035.130067
# 2.0    41756.735734
# 3.0    77452.500272
# Name: km, dtype: float64

# %%
df["age"].value_counts(dropna=False)
# Out:
# 1.0    5366
# 3.0    3678
# 0.0    3597
# 2.0    3278
# Name: age, dtype: int64

# %% [markdown]
# ## body_type

# %%
df['body_type'].value_counts(dropna=False)
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# NaN               350
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df.body_type.replace("Other", np.nan, inplace=True)

# %%
df['body_type'].value_counts(dropna=False)
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# NaN               350
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df["body_type"].mode()
# Out:
# 0    Sedans
# dtype: object

# %%
df["body_type"].mode()[0]
# Out:
# 'Sedans'

# %%
df["body_type"].fillna(df["body_type"].mode()[0])
# Out:
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
#           ...
# 15914       Van
# 15915       Van
# 15916       Van
# 15917       Van
# 15918       Van
# Name: body_type, Length: 15919, dtype: object

# %%
df['body_type'].value_counts(dropna=False)
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# NaN               350
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df.loc[df["make_model"]=="Audi A1", "body_type"].fillna(df[df["make_model"]=="Audi A1"]["body_type"].mode()[0])
# Out:
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
#          ...
# 2609     Sedans
# 2610     Sedans
# 2611     Sedans
# 2612    Compact
# 2613     Sedans
# Name: body_type, Length: 2614, dtype: object

# %%
df['body_type'].value_counts(dropna=False)
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# NaN               350
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
for group in list(df["make_model"].unique()):
    cond = df["make_model"]==group
    mode = list(df[cond]["body_type"].mode())
    if mode != []:
        df.loc[cond, "body_type"] = df.loc[cond, "body_type"].fillna(df[cond]["body_type"].mode()[0])
    else:
        df.loc[cond, "body_type"] = df.loc[cond, "body_type"].fillna(df["body_type"].mode()[0])

# %%
df['body_type'].value_counts(dropna=False)

# %%
def fill_most(df, group_col, col_name):
    '''Fills the missing values with the most existing value (mode) in the relevant column according to single-stage grouping'''
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        mode = list(df[cond][col_name].mode())
        if mode != []:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[cond][col_name].mode()[0])
        else:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[col_name].mode()[0])

# %%
fill_most(df, "make_model", "body_type")

# %% [markdown]
# ## Vat

# %%
df.vat= df.vat.fillna(method='ffill').fillna(method='bfill')

# %%
df.vat.value_counts(dropna=False)
# Out:
# VAT deductible      15048
# Price negotiable      871
# Name: vat, dtype: int64

# %% [markdown]
# ## Km

# %%
df.km.value_counts(dropna=False)
# Out:
# 10.0        1045
# NaN         1024
# 1.0          367
# 5.0          170
# 50.0         148
#             ...
# 160542.0       1
# 20719.0        1
# 91910.0        1
# 39860.0        1
# 57889.0        1
# Name: km, Length: 6690, dtype: int64

# %%
df.groupby("age").km.mean()
# Out:
# age
# 0.0     1647.362609
# 1.0    18035.130067
# 2.0    41756.735734
# 3.0    77452.500272
# Name: km, dtype: float64

# %%
df.groupby("age").km.transform("mean")
# Out:
# 0        77452.500272
# 1        41756.735734
# 2        77452.500272
# 3        77452.500272
# 4        77452.500272
#              ...
# 15914    18035.130067
# 15915     1647.362609
# 15916     1647.362609
# 15917     1647.362609
# 15918     1647.362609
# Name: km, Length: 15919, dtype: float64

# %%
df["km"].fillna(df.groupby("age").km.transform("mean"), inplace=True)

# %%
df.km.value_counts(dropna=False)
# Out:
# 10.000000       1045
# 18035.130067     876
# 1.000000         367
# 5.000000         170
# 50.000000        148
#                 ...
# 20719.000000       1
# 91910.000000       1
# 39860.000000       1
# 28084.000000       1
# 57889.000000       1
# Name: km, Length: 6692, dtype: int64

# %% [markdown]
# # Previous Owners

# %%
df['Previous_Owners'].value_counts(dropna=False) # NaN    6640 adet var
# Out:
# 1.0    8294
# NaN    6640
# 2.0     778
# 0.0     188
# 3.0      17
# 4.0       2
# Name: Previous_Owners, dtype: int64

# %%
df["Previous_Owners"].fillna("?", inplace = True)

# %%
df["Previous_Owners"].value_counts(dropna=False)
# Out:
# 1.0    8294
# ?      6640
# 2.0     778
# 0.0     188
# 3.0      17
# 4.0       2
# Name: Previous_Owners, dtype: int64

# %%
#                    1.0               99757.000000  173021.000000
#                    2.0               48606.000000  106820.000000
#                    3.0               29500.000000   29500.000000
#                    ?                 91000.000000  179521.000000
# Opel Insignia  0.0 0.0                   9.500000      10.000000
#                    1.0                5000.000000   20000.000000
#                    ?                  1647.362609   37500.000000
#                1.0 0.0               18035.130067   18035.130067
#                    1.0               28594.750000   70670.000000
#                    2.0               27265.500000   33660.000000
#                    ?                 18035.130067   39525.000000
#                2.0 0.0               40000.000000   40000.000000
#                    1.0               70275.000000  180033.000000
#                    2.0               47500.000000   70000.000000
#                    3.0               35918.750000   37125.000000
#                    ?                 89000.000000  145000.000000
#                3.0 1.0              126450.500000  232000.000000
#                    2.0               97600.000000  200000.000000
#                    3.0               60750.000000   67000.000000
#                    ?                 96862.000000  214999.000000
# Renault Clio   0.0 0.0                  10.000000      20.000000
#                    1.0                 150.000000    9998.000000
#                    2.0                  95.000000     500.000000
#                    ?                    20.000000  105000.000000
#                1.0 0.0               18035.130067   18035.130067
#                    1.0               19475.000000  113392.000000
#                    2.0               14785.000000   28000.000000
#                    ?                 24500.000000   80009.000000
#                2.0 0.0               86000.000000   86000.000000
#                    1.0               46212.000000  131494.000000
#                    2.0               29000.000000   54413.000000
#                    3.0               66000.000000   66000.000000
#                    ?                 45655.000000   84496.000000
#                3.0 0.0               36750.000000   36750.000000
#                    1.0               98000.000000  161556.000000
#                    2.0               49178.000000   93000.000000
#                    3.0               59000.000000   59000.000000
#                    ?                 93000.000000  163500.000000
# Renault Duster 0.0 ?                   101.000000     101.000000
#                1.0 0.0               18035.130067   18035.130067
#                    ?                 18035.130067   18035.130067
# Renault Espace 0.0 0.0                  55.000000     100.000000
#                    1.0                1647.362609   19900.000000
#                    2.0                1000.000000    1000.000000
#                    ?                  1000.000000   15000.000000
#                1.0 0.0               18035.130067   18035.130067
#                    1.0               19460.250000   48403.000000
#                    2.0               24550.000000   27000.000000
#                    ?                 18035.130067   62860.000000
#                2.0 1.0               55755.000000  113100.000000
#                    2.0               49606.000000   49606.000000
#                    3.0               46000.000000   46000.000000
#                    ?                 51382.000000  240000.000000
#                3.0 0.0               91883.000000   91883.000000
#                    1.0               98375.750000  197414.000000
#                    2.0               64921.250000  148000.000000
#                    3.0               40000.000000   40000.000000
#                    4.0               57000.000000   57000.000000
#                    ?                 94000.000000  169068.000000

# %%
df[(df["make_model"]=="Renault Duster") & (df["Previous_Owners"] == "?")]["km"]
# Out:
# 14894    18035.130067
# 14895    18035.130067
# 14896      101.000000
# 14897    18035.130067
# 14898      101.000000
# 14899      101.000000
# 14900    18035.130067
# 14901      101.000000
# 14903      101.000000
# 14904    18035.130067
# 14905    18035.130067
# 14906      101.000000
# 14907      101.000000
# 14908    18035.130067
# 14909    18035.130067
# 14910      101.000000
# 14911    18035.130067
# 14912      101.000000
# 14913    18035.130067
# 14914      101.000000
# 14915      101.000000
# 14916      101.000000
# 14917    18035.130067
# 14918    18035.130067
# 14919    18035.130067
# 14920      101.000000
# 14921    18035.130067
# 14922    18035.130067
# 14923      101.000000
# 14924    18035.130067
# 14925      101.000000
# 14926      101.000000
# 14927    18035.130067
# Name: km, dtype: float64

# %%
cond = (df["make_model"]=="Renault Duster") & (df["Previous_Owners"] == "?")
df.loc[cond, "Previous_Owners"] = df.loc[cond, "Previous_Owners"].replace("?", 0.0)

# %%
df["Previous_Owners"].value_counts(dropna=False)
# Out:
# 1.0    8294
# ?      6607
# 2.0     778
# 0.0     221
# 3.0      17
# 4.0       2
# Name: Previous_Owners, dtype: int64

# %%
df[(df["make_model"]=="Audi A1") & (df["Previous_Owners"] == "?")]["km"]
# Out:
# 1        80000.000000
# 9        16103.000000
# 10       11300.000000
# 13       45764.000000
# 16        9752.000000
# 18       50280.000000
# 19       13406.000000
# 23        9077.000000
# 25      115000.000000
# 28       14556.000000
# 29       22000.000000
# 30       38400.000000
# 34      126000.000000
# 52       27600.000000
# 53      111670.000000
# 59       55000.000000
# 65       41294.000000
# 66       64000.000000
# 67       13135.000000
# 70       17861.000000
# 81       13406.000000
# 85       26500.000000
# 86       58806.000000
# 94       51484.000000
# 95       14770.000000
# 96       12415.000000
# 97       26064.000000
# 100      12402.000000
# 101      14702.000000
# 103       9082.000000
# 104       9580.000000
# 105      10013.000000
# 106      10450.000000
# 107      14878.000000
# 108      10273.000000
# 109      47500.000000
# 110       9466.000000
# 111      18971.000000
# 112      31877.000000
# 113       9878.000000
# 115      76264.000000
# 116       6695.000000
# 118      12261.000000
# 122          1.000000
# 130      65000.000000
# 131      14493.000000
# 132      33500.000000
# 134      51000.000000
# 140      40000.000000
# 141      14551.000000
# 150      19990.000000
# 159      35816.000000
# 168      15000.000000
# 170      12000.000000
# 171      42000.000000
# 173      26299.000000
# 176      29159.000000
# 190      25330.000000
# 191      11300.000000
# 195      25751.000000
# 197      63136.000000
# 201      63136.000000
# 205      32700.000000
# 208      37702.000000
# 210      47750.000000
# 219      36400.000000
# 227      36625.000000
# 228      25000.000000
# 229      36041.000000
# 231      25000.000000
# 232      66000.000000
# 233      90000.000000
# 244      18800.000000
# 247      46000.000000
# 250      57178.000000
# 252      14000.000000
# 253      59500.000000
# 260      21000.000000
# 261      58033.000000
# 262      32000.000000
# 270      49198.000000
# 274      24550.000000
# 275      26000.000000
# 276      40800.000000
# 278       7701.000000
# 309      10000.000000
# 310     108000.000000
# 327      78000.000000
# 331      88800.000000
# 334      26310.000000
# 355      56000.000000
# 361      60000.000000
# 367      70000.000000
# 370      25000.000000
# 372      35730.000000
# 374      75000.000000
# 381      37000.000000
# 387      72761.000000
# 388      73575.000000
# 397     146140.000000
# 404      24000.000000
# 405      40528.000000
# 406     104000.000000
# 407      63473.000000
# 408      29950.000000
# 419      40000.000000
# 427      50272.000000
# 435      65838.000000
# 444      28978.000000
# 446      71000.000000
# 447      24999.000000
# 448      46400.000000
# 457      34000.000000
# 459      80000.000000
# 460      39838.000000
# 461      29600.000000
# 466      20000.000000
# 468      18371.000000
# 469      18371.000000
# 470      18371.000000
# 476      40200.000000
# 479      10000.000000
# 480     100000.000000
# 483      84500.000000
# 2531     18035.130067
# 2532         1.000000
# 2533         1.000000
# 2534     18035.130067
# 2536     18035.130067
# 2537       200.000000
# 2538       180.000000
# 2539     18035.130067
# 2540     18035.130067
# 2541        10.000000
# 2542      5000.000000
# 2543      4136.000000
# 2544     18035.130067
# 2545     18035.130067
# 2546     18035.130067
# 2547     18035.130067
# 2548       201.000000
# 2549        10.000000
# 2552      1090.000000
# 2553      3990.000000
# 2554      3990.000000
# 2559        10.000000
# 2562     18035.130067
# 2565     10000.000000
# 2566     18035.130067
# 2567        12.000000
# 2568     18035.130067
# 2569     18035.130067
# 2570     18035.130067
# 2571     18035.130067
# 2572        11.000000
# 2573     18035.130067
# 2574        50.000000
# 2576     18035.130067
# 2577        10.000000
# 2579        10.000000
# 2580     18035.130067
# 2581        10.000000
# 2583        10.000000
# 2584      1647.362609
# 2585        10.000000
# 2586       261.000000
# 2587        10.000000
# 2590       250.000000
# 2591       250.000000
# 2593      3317.000000
# 2596        32.000000
# 2597        12.000000
# 2598        50.000000
# 2599        50.000000
# 2601     18035.130067
# 2602     18035.130067
# 2603      4000.000000
# 2604        10.000000
# 2605      5000.000000
# 2606        50.000000
# 2607      1647.362609
# 2609     18035.130067
# 2610        10.000000
# 2613       390.000000
# Name: km, dtype: float64

# %%
cond = (df["make_model"]=="Audi A1") & (df["Previous_Owners"] == "?")
df.loc[cond, "Previous_Owners"] = df.loc[cond, "Previous_Owners"].replace("?", 1.0)

# %%
df["Previous_Owners"].replace("?", np.nan, inplace=True)

# %%
df["Previous_Owners"].value_counts(dropna=False)
# Out:
# 1.0    9352
# ?      5549
# 2.0     778
# 0.0     221
# 3.0      17
# 4.0       2
# Name: Previous_Owners, dtype: int64

# %%
for group in list(df["age"].unique()):
    cond = df["age"]==group
    df.loc[cond, "Previous_Owners"] = df.loc[cond, "Previous_Owners"].fillna(method="ffill").fillna(method="bfill")
df["Previous_Owners"] = df["Previous_Owners"].fillna(method="ffill").fillna(method="bfill")

# %%
df["Previous_Owners"].value_counts(dropna=False)
# Out:
# 1.0    14105
# 2.0     1101
# 0.0      682
# 3.0       29
# 4.0        2
# Name: Previous_Owners, dtype: int64

# %% [markdown]
# # hp_kW

# %%
df['hp_kW'].value_counts(dropna=False)
# Out:
# 85.0     2542
# 66.0     2122
# 81.0     1402
# 100.0    1308
# 110.0    1112
# 70.0      888
# 125.0     707
# 51.0      695
# 55.0      569
# 118.0     516
# 92.0      466
# 121.0     392
# 147.0     380
# 77.0      345
# 56.0      286
# 54.0      276
# 103.0     253
# 87.0      232
# 165.0     194
# 88.0      177
# 60.0      160
# 162.0      98
# NaN        88
# 74.0       81
# 96.0       72
# 71.0       59
# 101.0      47
# 67.0       40
# 154.0      39
# 122.0      35
# 119.0      30
# 164.0      27
# 135.0      24
# 82.0       22
# 52.0       22
# 1.0        20
# 78.0       20
# 146.0      18
# 294.0      18
# 141.0      16
# 57.0       10
# 120.0       8
# 104.0       8
# 191.0       7
# 112.0       7
# 155.0       6
# 117.0       6
# 184.0       5
# 90.0        4
# 76.0        4
#                              149.0  27990.0
#                              150.0  43545.0
#                              165.0  64332.0
#                              167.0  39990.0
#                              168.0  39990.0
#                              ?      39990.0

# %%
df["hp_kW"].replace("?", np.nan, inplace=True)

# %%
fill(df, "make_model", "body_type", "hp_kW", method="mode")

# %%
df["hp_kW"].value_counts(dropna=False)
# Out:
# 85.0     2543
# 66.0     2124
# 81.0     1403
# 100.0    1314
# 110.0    1113
# 70.0      890
# 125.0     711
# 51.0      696
# 55.0      589
# 118.0     550
# 92.0      466
# 121.0     392
# 147.0     380
# 77.0      353
# 56.0      294
# 54.0      276
# 103.0     253
# 87.0      232
# 165.0     194
# 88.0      177
# 60.0      160
# 162.0      98
# 74.0       81
# 96.0       72
# 71.0       59
# 101.0      47
# 67.0       40
# 154.0      39
# 122.0      35
# 119.0      30
# 164.0      27
# 135.0      24
# 52.0       22
# 82.0       22
# 78.0       20
# 1.0        20
# 146.0      18
# 294.0      18
# 141.0      16
# 57.0       10
# 120.0       8
# 104.0       8
# 191.0       7
# 112.0       7
# 155.0       6
# 117.0       6
# 184.0       5
# 76.0        4
# 65.0        4
# 90.0        4
# 80.0        3
# 98.0        3
# 168.0       3
# 93.0        3
# 149.0       3
# 150.0       2
# 89.0        2
# 63.0        2
# 86.0        2
# 53.0        2
# 270.0       2
# 127.0       2
# 228.0       2
# 40.0        2
# 143.0       2
# 167.0       2
# 140.0       2
# 239.0       1
# 44.0        1
# 195.0       1
# 132.0       1
# 133.0       1
# 115.0       1
# 163.0       1
# 9.0         1
# 4.0         1
# 84.0        1
# 137.0       1
# 123.0       1
# 75.0        1
# Name: hp_kW, dtype: int64

# %%
df['hp_kW'].isnull().value_counts(dropna=False)
# Out:
# False    15919
# Name: hp_kW, dtype: int64

# %% [markdown]
# ## Type

# %%
df["Type"].value_counts(dropna=False)
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# NaN                   2
# Name: Type, dtype: int64

# %%
df.Type.fillna("?", inplace=True)

# %%
df['Type'].value_counts(dropna=False)
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# ?                     2
# Name: Type, dtype: int64

# %%
df.groupby(["Type", "make_model", "age"]).km.describe()

# %%
cond1 = (df['make_model'] == "Audi A3") & (df["age"] == 0)
cond2 = (df['make_model'] == "Audi A3") & (df["age"] == 3)

# %%
df.loc[cond1,'Type'] = df.loc[cond1,'Type'].replace('?','New')
df.loc[cond2,'Type'] = df.loc[cond2,'Type'].replace('?','Used')

# %%
df['Type'].value_counts(dropna=False)

# %%
df['Type']= df['Type'].fillna(method='ffill')

# %%
df.Type.isnull().sum()

# %%
df['Type'].value_counts(dropna=False)

# %% [markdown]
# ## Inspection_new

# %%
df["Inspection_new"].value_counts(dropna=False)

# %%
df["Inspection_new"].fillna("?", inplace=True)

# %%
df["Inspection_new"].value_counts(dropna=False)

# %%
df.groupby(["make_model", "body_type", "age", "Inspection_new"]).price.describe()

# %%
df["Inspection_new"].replace("?", "No", inplace=True)

# %%
df["Inspection_new"].value_counts(dropna=False)

# %%
df["Inspection_new"].replace(["Yes", "No"], [1,0], inplace = True)

# %%
df["Inspection_new"].value_counts(dropna=False)

# %%
df['Inspection_new'].value_counts(normalize=True, dropna=False)

# %% [markdown]
# ## Warranty

# %%
df.Warranty.value_counts(dropna=False)

# %%
df["Warranty"].fillna("?", inplace = True)

# %%
df.groupby(['make_model', 'age', 'Warranty']).price.describe()

# %%
df.drop("Warranty", axis=1, inplace=True)

# %% [markdown]
# # Body Color

# %%
df["Body Color"].str.strip().value_counts(dropna=False)

# %%
df["Body Color"].fillna("?", inplace = True)

# %%
df.groupby(["make_model", "body_type", 'Body Color']).price.describe()

# %%
df.drop("Body Color", axis=1, inplace=True)

# %% [markdown]
# # Paint Type

# %%
df["Paint Type"]

# %%
df["Paint Type"].fillna("?", inplace = True)

# %%
df["Paint Type"].value_counts(dropna=False)

# %%
df.groupby(["make_model", "body_type", "age", 'Paint Type']).price.describe()

# %%
df["Paint Type"].replace("?", np.nan, inplace = True)

# %%
fill(df, "make_model", "body_type", "Paint Type", "ffill")

# %%
df["Paint Type"].value_counts(dropna=False)

# %% [markdown]
# # Upholstery_type

# %%
df["Upholstery_type"].value_counts(dropna=False)

# %%
df["Upholstery_type"].replace(["Velour", "alcantara", "Part leather", "Full leather"], ["Cloth", "Part/Full Leather", "Part/Full Leather", "Part/Full Leather"], inplace=True)

# %%
df["Upholstery_type"].value_counts(dropna=False)

# %%
fill(df, "make_model", "body_type", "Upholstery_type", "ffill")

# %%
df["Upholstery_type"].value_counts(dropna=False)

# %% [markdown]
# # Upholstery_color

# %%
df["Upholstery_color"].value_counts(dropna=False)

# %%
df.drop("Upholstery_color", axis=1, inplace=True)

# %% [markdown]
# # Nr. of Doors

# %%
df["Nr. of Doors"].value_counts(dropna=False)

# %%
fill(df, "make_model", "body_type", "Nr. of Doors", "mode")

# %%
fill(df, "make_model", "body_type", "Nr. of Doors", "ffill")

# %%
df["Nr. of Doors"].value_counts(dropna=False)

# %% [markdown]
# # Nr. of Seats

# %%
df["Nr_of_Seats"].value_counts(dropna=False)

# %%
fill(df, "make_model", "body_type", "Nr_of_Seats", "mode")

# %%
df["Nr_of_Seats"].value_counts(dropna=False)

# %%
fill(df, "make_model", "body_type", "Nr_of_Seats", "ffill")

# %%
df["Nr_of_Seats"].isnull().sum()

# %% [markdown]
# # Displacement_cc- 23NaN

# %%
df["Displacement_cc"].value_counts(dropna=False)

# %%
df["Displacement_cc"].fillna("?", inplace=True)

# %%
df.groupby(["make_model", "body_type","Displacement_cc"]).price.describe()

# %%
df["Displacement_cc"].value_counts(dropna=False)

# %%
df["Displacement_cc"].replace("?", np.nan, inplace=True)

# %%
fill(df, "make_model", "body_type", "Displacement_cc", "mode")

# %%
df["Displacement_cc"].value_counts(dropna=False)

# %% [markdown]
# # Cylinders

# %%
fill(df, "make_model", "body_type", "Cylinders", "mode")

# %%
df.drop("Cylinders", axis = 1, inplace = True)

# %% [markdown]
# # Weight

# %%
df["Weight_kg"].value_counts(dropna=False)

# %%
df["Weight_kg"].fillna("?", inplace=True)

# %%
df.groupby(["make_model", "body_type","Weight_kg"]).price.describe()

# %%
df["Weight_kg"].replace("?", np.nan, inplace=True)

# %%
fill(df, "make_model", "body_type", "Weight_kg", "mode")

# %%
df["Weight_kg"].value_counts(dropna=False)

# %% [markdown]
# # Drive chain-58 NaN

# %%
df["Drive_chain"].value_counts(dropna=False)

# %%
df["Drive_chain"].fillna("?", inplace=True)

# %%
df.groupby(["make_model", "body_type", "Drive_chain"]).price.describe()

# %%
cond = (df['make_model'] == "Renault Duster") & (df["body_type"] == "Off-Road")

# %%
df.loc[cond,'Drive_chain'] = df.loc[cond,'Drive_chain'].replace('?','4WD')

# %%
df["Drive_chain"].value_counts(dropna=False)

# %%
df["Drive_chain"] = df["Drive_chain"].replace('?', np.nan)

# %%
df["Drive_chain"].value_counts(dropna=False)

# %%
fill(df, "make_model", "body_type", "Drive_chain", "mode")

# %%
df["Drive_chain"].value_counts(dropna=False)

# %%
fill(df, "make_model", "body_type", "Drive_chain", "ffill")

# %%
df["Drive_chain"].value_counts(dropna=False)

# %% [markdown]
# # CO2 Emission

# %%
df["CO2_Emission"].value_counts(dropna=False)

# %%
df.info()

# %%
df["CO2_Emission"].fillna("?", inplace=True)

# %%
df.groupby(["make_model", "body_type","CO2_Emission"]).price.describe()

# %%
df["CO2_Emission"].replace("?", np.nan, inplace=True)

# %%
fill(df, "make_model", "body_type", "CO2_Emission", "median")

# %%
df.drop("CO2_Emission", axis=1, inplace=True)

# %% [markdown]
# # Emission_Class

# %%
df["Emission_Class"].value_counts(dropna=False)

# %%
df["Emission_Class"].fillna("?", inplace=True)

# %%
df["Emission_Class"].value_counts(dropna=False)

# %%
df.groupby(["make_model", "age", "Fuel", "Emission_Class"]).price.describe()

# %%
df["Emission_Class"].replace("?", np.nan, inplace=True)

# %%
df["Emission_Class"].value_counts(dropna=False)

# %%
fill(df, "age", "Fuel", "Emission_Class", "ffill")

# %%
df.drop("Emission_Class", axis=1, inplace=True)

# %% [markdown]
# # Comfort_Convenience

# %%
df["Comfort_Convenience"].value_counts(dropna=False).to_frame()

# %%
fill(df, "make_model", "body_type", "Comfort_Convenience", "mode")

# %%
df["Comfort_Convenience"].value_counts(dropna=False).to_frame()

# %% [markdown]
# # Entertainment_Media 36 NaN

# %%
df["Entertainment_Media"].value_counts(dropna=False).to_frame()

# %%
fill(df, "make_model", "body_type", "Entertainment_Media", "mode")

# %%
df["Entertainment_Media"].value_counts(dropna=False).to_frame()

# %% [markdown]
# # Extras

# %%
df["Extras"].value_counts(dropna=False).to_frame()

# %%
fill(df, "make_model", "body_type", "Extras", "mode")

# %%
df["Extras"].value_counts(dropna=False).to_frame()

# %%
df.Extras.isnull().sum()

# %% [markdown]
# # Safety_Security

# %%
df["Safety_Security"].value_counts(dropna=False).to_frame()

# %%
fill(df, "make_model", "body_type", "Safety_Security", "mode")

# %%
df["Safety_Security"].value_counts(dropna=False).to_frame()

# %%
df.Safety_Security.isnull().sum()

# %% [markdown]
# # Gears

# %%
df["Gears"].value_counts(dropna=False)

# %%
df["Gears"].fillna("?", inplace=True)

# %%
df["Gears"].value_counts(dropna=False)

# %%
df.groupby(["make_model", "body_type", "Gearing Type", "Gears"]).price.describe()

# %%
df["Gears"].replace([1,2,3,4,9,50,"?"], np.nan, inplace=True)

# %%
df["Gears"].value_counts(dropna=False)

# %%
for group1 in list(df["make_model"].unique()):
    for group2 in list(df["body_type"].unique()):
        for group3 in list(df["Gearing Type"].unique()):
            cond1 = df["make_model"]==group1
            cond2 = (df["make_model"]==group1) & (df["body_type"]==group2)
            cond3 = (df["make_model"]==group1) & (df["body_type"]==group2) & (df["Gearing Type"]==group3)
            mode1 = list(df[cond1]["Gears"].mode())
            mode2 = list(df[cond2]["Gears"].mode())
            mode3 = list(df[cond3]["Gears"].mode())
            if mode3 != []:
                df.loc[cond3, "Gears"] = df.loc[cond3, "Gears"].fillna(df[cond3]["Gears"].mode()[0])
            elif mode2 != []:
                df.loc[cond3, "Gears"] = df.loc[cond3, "Gears"].fillna(df[cond2]["Gears"].mode()[0])
            elif mode1 != []:
                df.loc[cond3, "Gears"] = df.loc[cond3, "Gears"].fillna(df[cond1]["Gears"].mode()[0])
            else:
                df.loc[cond3, "Gears"] = df.loc[cond3, "Gears"].fillna(df["Gears"].mode()[0])

# %%
df["Gears"].value_counts(dropna=False)

# %% [markdown]
# # Cons_Comb

# %%
df["Cons_Comb"].value_counts(dropna=False)

# %%
cons_comb = (df["Cons_Country"] + df["Cons_City"])/2

# %%
df["Cons_Comb"] = df["Cons_Comb"].fillna(cons_comb)

# %%
df["Cons_Comb"].fillna("?", inplace=True)

# %%
df.groupby(["make_model", "body_type","Cons_Comb"]).price.describe()

# %%
df["Cons_Comb"].replace([0.0, 1.0, 1.2, 1.6, 10, 11, 13.8, 32.0, 33.0, 38.0, 40.0, 43.0, 46.0, 50.0, 51.0, 54.0, 55.0, "?"], np.nan, inplace=True)

# %%
df["Cons_Comb"].value_counts(dropna=False)

# %%
lst1 = df.make_model.unique()
lst2 = df.body_type.unique()

for i in lst1:
    for j in lst2:
        cond = (df.make_model == i) & (df.body_type == j)
        df.loc[cond, 'Cons_Comb'] = df.loc[cond, 'Cons_Comb'].fillna(method='ffill').fillna(method='bfill')
for i in lst2:
    cond = df.body_type == i
    df.loc[cond, 'Cons_Comb'] = df.loc[cond, 'Cons_Comb'].fillna(method='ffill').fillna(method='bfill')
for i in lst1:
    cond = df.make_model == i
    df.loc[cond, 'Cons_Comb'] = df.loc[cond, 'Cons_Comb'].fillna(method='ffill').fillna(method='bfill')

# %%
df["Cons_Comb"].value_counts(dropna=False)

# %%
df.Cons_Comb.isnull().sum()

# %% [markdown]
# # Cons_City

# %%
df.drop("Cons_City", axis = 1, inplace = True)

# %% [markdown]
# # Cons_Country

# %%
df.drop("Cons_Country", axis = 1, inplace = True)

# %%
df.shape

# %%
df.isnull().sum()/df.shape[0]*100

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.to_csv("scout_car_filled_data_finished.csv", index=False)
