# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.ptplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16912/3344674442.py in <module>
#       2 import seaborn as sns
#       3 import numpy as np
# ----> 4 import matplotlib.ptplot as plt
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib.ptplot'

# %%
df=sns.get_dataset_names()
df

# %%
df=sns.load_dataset("tips")
df

# %%
df.head()

# %% [markdown]
# # catplot; colon ve row kullanarak subfigure olarak

# %%
titanic=sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Basic Libraries
import pandas as pd
import numpy as np
# Libraries for visualizaton
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.catplot(x="pclass", y="survived", data=titanic, kind="bar", estimator=np.sum, hue="sex");

# %%
sns.catplot(x="pclass", y="survived", data=titanic, kind="bar", estimator=np.count_nonzero, col="sex");

# %%
sns.catplot(x="pclass", y="survived", data=titanic, kind="bar", estimator=np.std, hue="sex");

# %%
sns.catplot(x="pclass", y="survived", data=titanic, kind="bar", estimator=np.std, hue="sex", col="alone", row="embarked");

# %%
sns.catplot(x="pclass", y="survived", data=titanic, kind="bar", estimator=np.std, hue="sex",  row="embarked");

# %%
sns.catplot(x="pclass", y="survived", data=titanic, kind="bar", estimator=np.std, hue="sex", col="alone");

# %%
sns.catplot(x="pclass", y="survived", data=titanic, kind="bar", estimator=np.std, hue="sex",  col="sex");

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="box");

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="box", hue="smoker");

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="violin", hue="smoker");

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="swarm", hue="smoker");

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="swarm", hue="smoker");

# %% [markdown]
# # joinplot; çarpıklık, sıklık vb .gösterir

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="scatter");

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex");

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="kde");

# %% [markdown]
# # pairplot

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
sns.pairplot(tips);

# %%
sns.pairplot(tips, hue="smoker");

# %%
sns.pairplot(tips, hue="sex");

# %%
sns.pairplot(tips, hue="sex", palette="viridis");

# %%
sns.pairplot(tips, hue="sex", palette="viridis", corner=True);

# %%
sns.pairplot(tips, hue="sex", palette="viridis", corner=True, diag_kind="hist");

# %%
sns.pairplot(tips, hue="sex", palette="viridis", corner=True, diag_kind="kde");

# %%
sns.pairplot(tips, hue="sex", palette="viridis", corner=True, diag_kind="auto");

# %% [markdown]
# # pairgrid

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g=sns.PairGrid(tips)
g=g.map(sns.scatterplot)

# %%
g=sns.PairGrid(tips)
g=g.map_upper(sns.scatterplot)
g=g.map_diag(sns.histplot)

# %%
g=sns.PairGrid(tips)
g=g.map_upper(sns.scatterplot)
g=g.map_diag(sns.histplot)
g=g.map_lower(sns.kdeplot, color="red")

# %%
g=sns.PairGrid(tips, hue="sex", palette="viridis")
g=g.map_upper(sns.scatterplot, linewidths=1, edgecolor="w", s=40)
g=g.map_diag(sns.histplot)
g=g.map_lower(sns.kdeplot)
g=g.add_legend();

# %%
g = sns.pairplot(tips)
g.map_lower(sns.kdeplot, color='purple')
g=map_upper(sns.kdeplot, color='g');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16912/566355027.py in <module>
#       1 g = sns.pairplot(tips)
#       2 g.map_lower(sns.kdeplot, color='purple')
# ----> 3 g=map_upper(sns.kdeplot, color='g');
#
# NameError: name 'map_upper' is not defined

# %% [markdown]
# # Facetgrid

# %%
g=sns.FacetGrid(tips, col="time", row="smoker")
g=g.map(plt.hist,"total_bill")

# %%
g=sns.FacetGrid(tips, col="time", row="smoker")
g=g.map(plt.scatter,"total_bill", "tip")

# %%
g=sns.FacetGrid(tips, col="time", row="smoker")
g=g.map(plt.scatter,"total_bill", "tip")

# %% [markdown]
# # Heatmap; sayısal değerlerin korelasyonuna bakar. kategorik değerler değil

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
g=sns.heatmap(data=tips.corr())

# %%
sns.heatmap(tips.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tips.corr(),annot=True, cmap="viridis") #renk değiştirmek için cmap kullanılır.
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tips.corr(),annot=True, cmap="viridis", center=1) # center ???
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tips.corr(),annot=True, cmap="viridis", center=2)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tips.corr(),annot=True, cmap="viridis", center=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # clustermap

# %%
sns.clustermap(tips.corr(),annot=True)

# %%
sns.clustermap(tips.corr(),annot=True)

# %%
iris=sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris = sns.load_dataset("iris")
species = iris.pop("species")
sns.clustermap(iris)

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# # catplot

# %%
sns.heatmap(penguins.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x="species", y="bill_length_mm", data=penguins)

# %%
sns.catplot(x="species", y="bill_length_mm", data=penguins, hue="sex", kind="bar")

# %%
sns.catplot(x="species", y="bill_length_mm", data=penguins, hue="sex", kind="strip")

# %%
sns.catplot(x="species", y="bill_length_mm", data=penguins, hue="sex", kind="strip", col="island")

# %%
sns.catplot(x="species", y="bill_length_mm", data=penguins, hue="sex", kind="bar", col="island")

# %%
sns.catplot(x='species', y="body_mass_g", data=penguins, kind="bar", row="sex", col="island" )

# %%
sns.catplot(x='species', y="body_mass_g", data=penguins, kind="box", row="sex", col="island" )

# %%
sns.catplot(x='species', y="body_mass_g", data=penguins, kind="box", row="sex", col="island" )

# %% [markdown]
# # joinplot

# %%
sns.jointplot(x='flipper_length_mm', y="body_mass_g", data=penguins )

# %%
sns.jointplot(x='flipper_length_mm', y="body_mass_g", data=penguins, kind="reg")

# %%
sns.jointplot(x='flipper_length_mm', y="body_mass_g", data=penguins, kind="kde")

# %%
sns.jointplot(x='flipper_length_mm', y="body_mass_g", data=penguins, kind="hist")

# %%
sns.jointplot(x='flipper_length_mm', y="body_mass_g", data=penguins, kind="hex")

# %%
sns.jointplot(x='flipper_length_mm', y="body_mass_g", data=penguins, hue="species")

# %%
sns.jointplot(x='flipper_length_mm', y="body_mass_g", data=penguins, hue="species")
