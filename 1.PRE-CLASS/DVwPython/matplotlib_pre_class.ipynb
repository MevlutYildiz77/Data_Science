# %% [markdown]
# To use Matplotlib plots on python

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# FORMAT STRING IN PLOT

# %%
x =[1,2,3,4,5,6,7]
y = 50,51,52,48,47,49,46

# %%
plt.plot(x,y)

# %%
plt.plot(x,y, 'g')

# %%
plt.plot(x,y, 'g+')

# %%
plt.plot(x,y, 'g+--')

# %%
plt.plot(x,y, 'g+-.')

# %%
plt.plot(x,y, '--r+')

# %%
plt.plot(x,y, 'r+--')

# %%
plt.plot(x,y, 'rD--')

# %%
plt.plot(x,y, 'rD')

# %%
plt.plot(x,y,color='red',marker='D',linestyle='')

# %%
plt.plot(x,y,color='#008000',marker='D',linestyle='')

# %%
plt.plot(x,y,color='#008040',marker='D',linestyle='')

# %%
plt.plot(x,y,color='red',marker='D',linestyle='',markersize=20)

# %%
plt.plot(x,y,color='red',marker='+',linestyle='',markersize=20)

# %%
# alpha used for the transperency of the plot. it is around 0-1
plt.plot(x,y,color='green',alpha=0.8)

# %%
plt.plot(x,y,color='green',alpha=0.2)

# %%
#Functional Method
plt.subplot(2,1,1)
plt.plot(x1, y1)
plt.subplot(2,1,2)
plt.plot(x2, x2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12508/4251867032.py in <module>
#       1 #Functional Method
#       2 plt.subplot(2,1,1)
# ----> 3 plt.plot(x1, y1)
#       4 plt.subplot(2,1,2)
#       5 plt.plot(x2, x2)
#
# NameError: name 'x1' is not defined

# %%
#Object-Oritented Method
fig,axes=plt.subplots(1,2)      # or
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x ,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12088/2320580437.py in <module>
#       2 fig,axes=plt.subplots(1,2)      # or
#       3 fig,axes=plt.subplots(nrows=1,ncols=2)
# ----> 4 axes[0].plot(x ,y)
#
# NameError: name 'x' is not defined

# %%
conda install matplotlib
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
plt.plot([1,2,3,4,5], [1,2,3,4,10], 'go')
plt.show()

# %% [markdown]
# AXEX LABELS, LEGEND, GRID

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
days= [1,2,3,4,5,6,7]
max_t = [50,51,52,48,47,49,46]
min_t= [43,42,40,44,33,35,37] 
avg_t=[45,48,48,46,40,42,41]

# %%
plt.xlabel("Days") 
plt.ylabel("Temperature")
plt.title("Weather")

plt.plot(days, max_t, label="Max")
plt.plot(days, min_t, label="Min")
plt.plot(days, avg_t, label="Avg")

plt.legend()
plt.grid()   
#plt.legend(loc="upper right")
#plt.legend(loc="best")   #default
#plt.legend(loc="best", shadow=True)
#plt.legend(loc="best", shadow=True, fontsize="large") # fontsize="small"

# %%
days= [1,2,3,4,5,6,7]
max_t = [32,51,52,48,47,49,46]
min_t= [43,42,40,44,33,35,37] 
avg_t=[45,48,48,46,40,42,41]

# %%
plt.xlabel("Days") 
plt.ylabel("Temperature")
plt.title("Weather")

plt.plot(days, max_t, label="Max")
plt.plot(days, min_t, label="Min")
plt.plot(days, avg_t, label="Avg")

plt.legend()   
#plt.legend(loc="upper right")
#plt.legend(loc="best")   #default
#plt.legend(loc="best", shadow=True)

# %% [markdown]
# SUBPLOTS WITH MATPLOTLIB IN PYTHON

# %%
import numpy as np
import random

# %%
x =np.linspace(0,10,10)
y1 = x
y2 = x**2
y3=x**3
y4=np.sqrt(x)
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,y1,'ro')
plt.title('$y_1=x$')

plt.subplot(2,2,2)
plt.plot(x,y2,'g--')
plt.title('$y_2=x^2$')

plt.subplot(2,2,3)
plt.plot(x,y3,'b^')
plt.title('$y_3=x^3$')

plt.subplot(2,2,4)
plt.plot(x,y1,'ks')
plt.title('$y_4=\sqrt{x}$')
# Out:
# Text(0.5, 1.0, '$y_4=\\sqrt{x}$')

# %%
x =np.linspace(0,10,10)
y1 = x
y2 = x**2
y3=x**3
y4=np.sqrt(x)
plt.figure()
plt.subplot(4,1,1)
plt.plot(x,y1,'ro')
plt.title('$y_1=x$')

plt.subplot(4,1,2)
plt.plot(x,y2,'g--')
plt.title('$y_2=x^2$')

plt.subplot(4,1,3)
plt.plot(x,y3,'b^')
plt.title('$y_3=x^3$')

plt.subplot(4,1,4)
plt.plot(x,y1,'ks')
plt.title('$y_4=\sqrt{x}$')
# Out:
# Text(0.5, 1.0, '$y_4=\\sqrt{x}$')

# %% [markdown]
# MATLOTLIB OBJECT-ORIENTED FIGURE PLOTS

# %%
from matplotlib import pyplot as plt
import numpy as np
import math
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title("sine wave")
ax.set_xlabel('angle')
ax.set_ylabel('sine')
plt.show()

# %%
x = np.arange(0, 10, 0.1)
y = np.sin(np.pi * x) + x
 
fig, ax = plt.subplots(1)
ax.plot(x, y)
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
x = np.arange(0,10,0.1)
ys = [np.sin(np.pi*x) + x,
      np.sin(np.pi*x) * x,
      np.sin(np.pi*x) / x]
 
fig, ax = plt.subplots(3)
ax[0].plot(x,ys[0])
ax[1].plot(x,ys[1])
ax[2].plot(x,ys[2])
 
ax[0].set_title("Addition")
ax[1].set_title("Multiplication")
ax[2].set_title("Division")
 
for a in ax:
    a.set_xlabel("x")
    a.set_ylabel("y")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_9340/2735275259.py:4: RuntimeWarning: invalid value encountered in true_divide
#   np.sin(np.pi*x) / x]

# %%
x = np.arange(0,10,0.1)
ys = [np.sin(np.pi*x) + x,
      np.sin(np.pi*x) * x,
      np.sin(np.pi*x) / x]
 
fig, ax = plt.subplots(3)
titles = ["Addition", "Multiplication", "Division"]
for idx, a in enumerate(ax):
    a.plot(x, ys[idx])
    a.set_title(titles[idx])
    a.set_xlabel("x")
    a.set_ylabel("y")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_9340/791318287.py:4: RuntimeWarning: invalid value encountered in true_divide
#   np.sin(np.pi*x) / x]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,3)
ax3 = fig.add_subplot(3,2,2)
ax4 = fig.add_subplot(3,2,4)
ax5 = fig.add_subplot(3,2,6)

# %% [markdown]
# STYLING(COLOR ETC)

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib import style

# %%
#style.use('ggplot')  #fivethirtyeight,darkgrey, grayscale

x = np.arange(0,30,0.2)
y = np.sin(x)

#plt.grid(True)
plt.title("Sine function")
plt.suptitle("I am bigger") 
plt.xlabel("weight of student") 
plt.ylabel("height of student")

plt.plot(x,y) 
plt.show()

# %%
#style.use('ggplot')  #fivethirtyeight,darkgrey, grayscale

x = np.arange(0,30,0.2)
y1 = np.sin(x) 
y2 = np.cos(x) 




plt.plot(x,y1,label="sine") 
plt.plot(x,y2,label="Cosine") 
plt.legend(loc="lower right")
plt.show()

# %%
--------------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 5, 11)
fig, axes = plt.subplots()    
axes.plot(x, x**2, label="square")
axes.plot(x, x**3, label="cube")
axes.legend()
fig.savefig("square_cube.png")

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 5, 11)
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(x, x+13, color="green", lw=3, ls='-', marker='o', markersize=10)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 11)
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(x, x+13, color="green", lw=3, ls='-', marker='o', markersize=10)
ax.set_xlim([0, 3])
ax.set_ylim([13, 16])
# Out:
# (13.0, 16.0)

# %% [markdown]
# BAR CHART

# %%
company= ["google", "amzn","mstf","fb"] 
revenue = [90,136, 89,27] 
profit= [40,2,34,12]
ypos= np.arange(len(company))
ypos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xticks(ypos,company) 
plt.ylabel("revenue(bln)") 
plt.title("US Teck Stokcs")
plt.bar(ypos, revenue, label="revenue")
plt.legend()

# %%
company= ["google", "amzn","mstf","fb"] 
revenue = [90,136, 89,27] 
profit= [40,2,34,12]
xpos= np.arange(len(company))
xpos
plt.xticks(ypos,company) 
plt.ylabel("revenue(bln)") 
plt.title("US Teck Stokcs")
plt.bar(xpos, revenue, label="revenue")
plt.bar(xpos, profit, label="Profit")
plt.legend()

# %%
# company= ["google", "amzn","mstf","fb"] 
# revenue = [90,136, 89,27] 
# profit= [40,2,34,12]
# xpos= np.arange(len(company))
# xpos
plt.xticks(ypos,company) 
plt.ylabel("revenue(bln)") 
plt.title("US Teck Stokcs")
plt.bar(xpos-0.2, revenue, width=0.4, label="revenue")
plt.bar(xpos+0.2, profit, width=0.4, label="Profit")
plt.legend()

# %%
company= ["google", "amzn","mstf","fb"] 
revenue = [90,136, 89,27] 
profit= [40,2,34,12]
xpos= np.arange(len(company))
xpos

plt.yticks(ypos,company) 
plt.title("US Teck Stokcs")
plt.bar(xpos-0.2, revenue, label="revenue")
plt.bar(xpos+0.2, profit, label="Profit")
plt.legend()

# %%
plt.yticks(ypos,company) 
plt.title("US Teck Stokcs")
plt.barh(xpos-0.2, revenue, label="revenue")
plt.barh(xpos+0.2, profit, label="Profit")
plt.legend()

# %% [markdown]
# HISTOGRAM

# %%
blood_sugar=[113,85,90,150,149,88,93,115,135,80,77,82,129]
plt.hist(blood_sugar)
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
blood_sugar=[113,85,90,150,149,88,93,115,135,80,77,82,129]
plt.hist(blood_sugar, bins=3, rwidth=0.95)
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar=[113,85,90,150,149,88,93,115,135,80,77,82,129]
plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95)
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar=[113,85,90,150,149,88,93,115,135,80,77,82,129]
plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, color='g')
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar_men=[113,85,90,150,149,88,93,115,135,80,77,82,129]
blood_sugar_women=[67,98,89,120,133,150,84,69,89,79,120,112,100]

plt.xlabel('sugar range')
plt.ylabel('Total no of patients')
plt.title('Blood sugar analysis')
plt.hist([blood_sugar_men, blood_sugar_women], bins=[80,100,125,150], rwidth=0.95, color=['green','orange'],label=['men','women'])
plt.legend()

# %%
blood_sugar_men=[113,85,90,150,149,88,93,115,135,80,77,82,129]
blood_sugar_women=[67,98,89,120,133,150,84,69,89,79,120,112,100]

plt.xlabel('sugar range')
plt.ylabel('Total no of patients')
plt.title('Blood sugar analysis')
plt.hist([blood_sugar_men, blood_sugar_women], bins=[80,100,125,150], rwidth=0.95, color=['green','orange'],label=['men','women'], orientation='horizontal')
plt.legend()

# %% [markdown]
# PIE CHART

# %% [markdown]
# Matplotlib-Subplots-Functional Method

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]
salary = [38496, 42000, 46752, 49320, 53200, 56000, 62316, 64928, 67317, 68748, 73752]

# %%
plt.subplot(2,1,1)
plt.plot(age, salary,"r")

plt.subplot(2,1,2)
plt.plot(age, salary_2, "b")

plt.show()

# %% [markdown]
# Subplots-Object-Oritented Method

# %%
fig, ax=plt.subplots(2,1)
ax[0].plot(age,salary, 'r')
ax[1].plot(age,salary,'b')

plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
