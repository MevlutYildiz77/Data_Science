# %%
import pandas as pd
import numpy as np

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 3 tane excel_sheet birleştirildi.
df = pd.concat(pd.read_excel('Sample - Superstore.xls', sheet_name= None), ignore_index=True)
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     1.0  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1     2.0  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2     3.0  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3     4.0  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4     5.0  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10798 entries, 0 to 10797
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID            9994 non-null   float64
#  1   Order ID          10794 non-null  object
#  2   Order Date        9994 non-null   datetime64[ns]
#  3   Ship Date         9994 non-null   datetime64[ns]
#  4   Ship Mode         9994 non-null   object
#  5   Customer ID       9994 non-null   object
#  6   Customer Name     9994 non-null   object
#  7   Segment           9994 non-null   object
#  8   Country/Region    9994 non-null   object
#  9   City              9994 non-null   object
#  10  State             9994 non-null   object
#  11  Postal Code       9983 non-null   float64
#  12  Region            9998 non-null   object
#  13  Product ID        9994 non-null   object
#  14  Category          9994 non-null   object
#  15  Sub-Category      9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9983.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55245.233297    229.858001     3.789574     0.156203
# std    2885.163629  32038.715955    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  57103.000000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10798, step=1)

# %%
# tablonun sütunlarını görme
df.keys()
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Regional Manager', 'Returned'],
#       dtype='object')

# %%
#tablonun değerlerini görme
df.values
# Out:
# array([[1.0, 'CA-2020-152156', Timestamp('2020-11-08 00:00:00'), ...,
#         41.9136, nan, nan],
#        [2.0, 'CA-2020-152156', Timestamp('2020-11-08 00:00:00'), ...,
#         219.58199999999997, nan, nan],
#        [3.0, 'CA-2020-138688', Timestamp('2020-06-12 00:00:00'), ...,
#         6.8713999999999995, nan, nan],
#        ...,
#        [nan, 'US-2021-151127', NaT, ..., nan, nan, 'Yes'],
#        [nan, 'US-2021-155999', NaT, ..., nan, nan, 'Yes'],
#        [nan, 'US-2021-155999', NaT, ..., nan, nan, 'Yes']], dtype=object)

# %%
#see the wanted rows(here from 10 to 14)
df.loc[10:14]
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 10    11.0  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710
# 11    12.0  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710
# 12    13.0  CA-2021-114412 2021-04-15 2021-04-20  Standard Class    AA-10480
# 13    14.0  CA-2020-161389 2020-12-05 2020-12-10  Standard Class    IM-15070
# 14    15.0  US-2019-118983 2019-11-22 2019-11-26  Standard Class    HP-14815
#
#       Customer Name      Segment Country/Region         City  ...  \
# 10  Brosina Hoffman     Consumer  United States  Los Angeles  ...
# 11  Brosina Hoffman     Consumer  United States  Los Angeles  ...
# 12     Andrew Allen     Consumer  United States      Concord  ...
# 13     Irene Maddox     Consumer  United States      Seattle  ...
# 14    Harold Pawlan  Home Office  United States   Fort Worth  ...
#
#          Product ID         Category Sub-Category  \
# 10  FUR-TA-10001539        Furniture       Tables
# ...

# %%
#just see wanted colums
df[['Order Date','Ship Date']]
# Out:
#       Order Date  Ship Date
# 0     2020-11-08 2020-11-11
# 1     2020-11-08 2020-11-11
# 2     2020-06-12 2020-06-16
# 3     2019-10-11 2019-10-18
# 4     2019-10-11 2019-10-18
# ...          ...        ...
# 10793        NaT        NaT
# 10794        NaT        NaT
# 10795        NaT        NaT
# 10796        NaT        NaT
# 10797        NaT        NaT
#
# [10798 rows x 2 columns]

# %%
#just see wanted colums
df.loc[:,['Order Date', 'Ship Date']]
# Out:
#       Order Date  Ship Date
# 0     2020-11-08 2020-11-11
# 1     2020-11-08 2020-11-11
# 2     2020-06-12 2020-06-16
# 3     2019-10-11 2019-10-18
# 4     2019-10-11 2019-10-18
# ...          ...        ...
# 10793        NaT        NaT
# 10794        NaT        NaT
# 10795        NaT        NaT
# 10796        NaT        NaT
# 10797        NaT        NaT
#
# [10798 rows x 2 columns]

# %%
# Select the data in rows [3, 4, 8] and in seelcted columns (['animal', 'age'])
df.loc[df.index[[3,4,8]],['Order Date', 'Ship Date']]
# Out:
#   Order Date  Ship Date
# 3 2019-10-11 2019-10-18
# 4 2019-10-11 2019-10-18
# 8 2018-06-09 2018-06-14

# %%
# Select only the rows where the Order Date is greater than 2018-06-09.
df[df["Order Date"] > '2018-06-09']
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0        1.0  CA-2020-152156 2020-11-08 2020-11-11    Second Class
# 1        2.0  CA-2020-152156 2020-11-08 2020-11-11    Second Class
# 2        3.0  CA-2020-138688 2020-06-12 2020-06-16    Second Class
# 3        4.0  US-2019-108966 2019-10-11 2019-10-18  Standard Class
# 4        5.0  US-2019-108966 2019-10-11 2019-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9988  9989.0  CA-2021-163629 2021-11-17 2021-11-21  Standard Class
# 9990  9991.0  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9991  9992.0  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9992  9993.0  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9993  9994.0  CA-2021-119914 2021-05-04 2021-05-09    Second Class
#
#      Customer ID    Customer Name    Segment Country/Region             City  \
# 0       CG-12520      Claire Gute   Consumer  United States        Henderson
# ...

# %%
# Select the rows where the Postal Code is missing, i.e. it is NaN .
df[df['Order Date'].isnull()]
# Out:
#        Row ID        Order ID Order Date Ship Date Ship Mode Customer ID  \
# 9994      NaN             NaN        NaT       NaT       NaN         NaN
# 9995      NaN             NaN        NaT       NaT       NaN         NaN
# 9996      NaN             NaN        NaT       NaT       NaN         NaN
# 9997      NaN             NaN        NaT       NaT       NaN         NaN
# 9998      NaN  CA-2018-100762        NaT       NaT       NaN         NaN
# ...       ...             ...        ...       ...       ...         ...
# 10793     NaN  US-2021-147886        NaT       NaT       NaN         NaN
# 10794     NaN  US-2021-147998        NaT       NaT       NaN         NaN
# 10795     NaN  US-2021-151127        NaT       NaT       NaN         NaN
# 10796     NaN  US-2021-155999        NaT       NaT       NaN         NaN
# 10797     NaN  US-2021-155999        NaT       NaT       NaN         NaN
#
#       Customer Name Segment Country/Region City  ... Product ID  Category  \
# ...

# %% [markdown]
# # 35' inci maddede kaldım.
